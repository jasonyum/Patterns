# %% [markdown]
# ### Practicing regular expressions
#
# Python has a powerful library called regular expressions that handle these searching / extracting tasks elegantly. The syntax is a little different, so they're like they're own mini programming language.
#
# - re.search()
# - re.findall()
# - ^ matches the beginning of the line
# - $ matches the end of the line
# - \s matches a whitepsace character
# - \S matches a non-whitespace character (opposite of \s)
# - * applies to the immediately preceding characters and indicates to match zero or more times
# - *? applies to the immediately preceding characters and indicates to match zero or more times in a non-greedy mode
# - + applies to the immediately preceding characters and indicates to match one or more times (this is like greedy)
# - +? applies to the immediately preceding characters and indicates to match one or more times in "non-greedy" mode
# - ? -> preceding character and indicates to match zero or one time
# - [aeiou] matches a single character as long as that character is in teh specified set so [aeiou] matches "a" , "e" , "i" etc but no other characters
# - [a-z0-9] you can specify ranges of characters using the minus sign
# - [^A-Za-z] when the first character is ^ then it inverts the logic, this example matches a single character that is anything other than an uppercase or lowercase letter
# - ( ) when parenthesis are added to a regular expression, they are ignored (the parenthesis, literally), but allow you to extract a particular subset of the matched string rather than the whole string when using findall()

# %%
import re 

hand = open('mbox-short.txt') 
for line in hand: 
    line = line.rstrip()
    if re.search('From:', line): 
        print(line) 

# could have used line.find() to accomplish the same result 
# the power comes when we need to use special characters like the caret ^
# The ^ character is used for regular expressions to match the beginning
# of a line... so it's much more specific. 

hand = open('mbox-short.txt')
for line in hand: 
    line = line.rstrip() 
    if re.search('^From:', line): 
        print(line) 

# Still, you could hve done this with startswith() method
# So this is contrived / simple example
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: mmmay@indiana.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: gopal.ramasammycook@gmail.com
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: stuart.freeman@et.gatech.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: wagnermr@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: tnguyen@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: wagnermr@iupui.edu
# From: gopal.ramasammycook@gmail.com
# From: ray@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: zqian@umich.edu
# From: wagnermr@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: chmaurer@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: aaronz@vt.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: ian@caret.cam.ac.uk
# From: ian@caret.cam.ac.uk
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: wagnermr@iupui.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: rjlowe@iupui.edu
# From: jimeng@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: gsilver@umich.edu
# From: ian@caret.cam.ac.uk
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: josrodri@iupui.edu
# From: josrodri@iupui.edu
# From: csev@umich.edu
# From: ian@caret.cam.ac.uk
# From: csev@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: cwen@iupui.edu
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: bkirschn@umich.edu
# From: jimeng@umich.edu
# From: ian@caret.cam.ac.uk
# From: stephen.marquard@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: ian@caret.cam.ac.uk
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: ray@media.berkeley.edu
# From: ian@caret.cam.ac.uk
# From: ian@caret.cam.ac.uk
# From: stuart.freeman@et.gatech.edu
# From: bkirschn@umich.edu
# From: zqian@umich.edu
# From: louis@media.berkeley.edu
# From: dlhaines@umich.edu
# From: bkirschn@umich.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: zqian@umich.edu
# From: bkirschn@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: bkirschn@umich.edu
# From: bkirschn@umich.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: bkirschn@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: dlhaines@umich.edu
# From: josrodri@iupui.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: hu2@iupui.edu
# From: louis@media.berkeley.edu
# From: bkirschn@umich.edu
# From: josrodri@iupui.edu
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: josrodri@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: hu2@iupui.edu
# From: cwen@iupui.edu
# From: tnguyen@iupui.edu
# From: sgithens@caret.cam.ac.uk
# From: arwhyte@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: david.horwitz@uct.ac.za
# From: josrodri@iupui.edu
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: david.horwitz@uct.ac.za
# From: dlhaines@umich.edu
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: gbhatnag@umich.edu
# From: dlhaines@umich.edu
# From: jimeng@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: rjlowe@iupui.edu
# From: jimeng@umich.edu
# From: wagnermr@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: wagnermr@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: mmmay@indiana.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: gopal.ramasammycook@gmail.com
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: stuart.freeman@et.gatech.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: wagnermr@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: tnguyen@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: wagnermr@iupui.edu
# From: gopal.ramasammycook@gmail.com
# From: ray@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: zqian@umich.edu
# From: wagnermr@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: chmaurer@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: aaronz@vt.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: ian@caret.cam.ac.uk
# From: ian@caret.cam.ac.uk
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: wagnermr@iupui.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: rjlowe@iupui.edu
# From: jimeng@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: gsilver@umich.edu
# From: ian@caret.cam.ac.uk
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: josrodri@iupui.edu
# From: josrodri@iupui.edu
# From: csev@umich.edu
# From: ian@caret.cam.ac.uk
# From: csev@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: cwen@iupui.edu
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: bkirschn@umich.edu
# From: jimeng@umich.edu
# From: ian@caret.cam.ac.uk
# From: stephen.marquard@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: ian@caret.cam.ac.uk
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: ray@media.berkeley.edu
# From: ian@caret.cam.ac.uk
# From: ian@caret.cam.ac.uk
# From: stuart.freeman@et.gatech.edu
# From: bkirschn@umich.edu
# From: zqian@umich.edu
# From: louis@media.berkeley.edu
# From: dlhaines@umich.edu
# From: bkirschn@umich.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: zqian@umich.edu
# From: bkirschn@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: bkirschn@umich.edu
# From: bkirschn@umich.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: bkirschn@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: dlhaines@umich.edu
# From: josrodri@iupui.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: hu2@iupui.edu
# From: louis@media.berkeley.edu
# From: bkirschn@umich.edu
# From: josrodri@iupui.edu
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: josrodri@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: hu2@iupui.edu
# From: cwen@iupui.edu
# From: tnguyen@iupui.edu
# From: sgithens@caret.cam.ac.uk
# From: arwhyte@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: david.horwitz@uct.ac.za
# From: josrodri@iupui.edu
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: david.horwitz@uct.ac.za
# From: dlhaines@umich.edu
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: gbhatnag@umich.edu
# From: dlhaines@umich.edu
# From: jimeng@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: rjlowe@iupui.edu
# From: jimeng@umich.edu
# From: wagnermr@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: wagnermr@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %%
# match any of the strings "From:", "Fxxm:", "F12m:" etc.. 
# Use '^...' to find these lines at the beginning! 

import re
hand = open('mbox-short.txt') 
for line in hand: 
    line = line.rstrip()
    if re.search('^F..m:', line): 
        print(line)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: mmmay@indiana.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: gopal.ramasammycook@gmail.com
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: stuart.freeman@et.gatech.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: wagnermr@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: tnguyen@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: wagnermr@iupui.edu
# From: gopal.ramasammycook@gmail.com
# From: ray@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: zqian@umich.edu
# From: wagnermr@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: chmaurer@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: aaronz@vt.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: ian@caret.cam.ac.uk
# From: ian@caret.cam.ac.uk
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: wagnermr@iupui.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: rjlowe@iupui.edu
# From: jimeng@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: gsilver@umich.edu
# From: ian@caret.cam.ac.uk
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: josrodri@iupui.edu
# From: josrodri@iupui.edu
# From: csev@umich.edu
# From: ian@caret.cam.ac.uk
# From: csev@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: cwen@iupui.edu
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: bkirschn@umich.edu
# From: jimeng@umich.edu
# From: ian@caret.cam.ac.uk
# From: stephen.marquard@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: ian@caret.cam.ac.uk
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: ray@media.berkeley.edu
# From: ian@caret.cam.ac.uk
# From: ian@caret.cam.ac.uk
# From: stuart.freeman@et.gatech.edu
# From: bkirschn@umich.edu
# From: zqian@umich.edu
# From: louis@media.berkeley.edu
# From: dlhaines@umich.edu
# From: bkirschn@umich.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: zqian@umich.edu
# From: bkirschn@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: bkirschn@umich.edu
# From: bkirschn@umich.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: bkirschn@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: dlhaines@umich.edu
# From: josrodri@iupui.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: hu2@iupui.edu
# From: louis@media.berkeley.edu
# From: bkirschn@umich.edu
# From: josrodri@iupui.edu
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: josrodri@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: hu2@iupui.edu
# From: cwen@iupui.edu
# From: tnguyen@iupui.edu
# From: sgithens@caret.cam.ac.uk
# From: arwhyte@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: david.horwitz@uct.ac.za
# From: josrodri@iupui.edu
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: david.horwitz@uct.ac.za
# From: dlhaines@umich.edu
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: gbhatnag@umich.edu
# From: dlhaines@umich.edu
# From: jimeng@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: rjlowe@iupui.edu
# From: jimeng@umich.edu
# From: wagnermr@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: wagnermr@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %%
# using the .+ wildcard
# Now the search string 'From:.+@' will match lines that start from 
# "From:", followed by one or more characters (.+), followed by an @-sign.

import re
hand = open('mbox-short.txt')
for line in hand: 
    line = line.rstrip()
    if re.search('^From:.+@', line): 
        print(line) 

# this catches things like ... 
# From: jason_yum@email.com
# You can see that it's "greedy" / "pushy" behavior in that it grabs
# extra strings, like the characters to the right of @, too.
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: mmmay@indiana.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: gopal.ramasammycook@gmail.com
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: stuart.freeman@et.gatech.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: wagnermr@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: tnguyen@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: wagnermr@iupui.edu
# From: gopal.ramasammycook@gmail.com
# From: ray@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: zqian@umich.edu
# From: wagnermr@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: chmaurer@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: aaronz@vt.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: ian@caret.cam.ac.uk
# From: ian@caret.cam.ac.uk
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: wagnermr@iupui.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: rjlowe@iupui.edu
# From: jimeng@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: gsilver@umich.edu
# From: ian@caret.cam.ac.uk
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: josrodri@iupui.edu
# From: josrodri@iupui.edu
# From: csev@umich.edu
# From: ian@caret.cam.ac.uk
# From: csev@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: cwen@iupui.edu
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: bkirschn@umich.edu
# From: jimeng@umich.edu
# From: ian@caret.cam.ac.uk
# From: stephen.marquard@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: ian@caret.cam.ac.uk
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: ray@media.berkeley.edu
# From: ian@caret.cam.ac.uk
# From: ian@caret.cam.ac.uk
# From: stuart.freeman@et.gatech.edu
# From: bkirschn@umich.edu
# From: zqian@umich.edu
# From: louis@media.berkeley.edu
# From: dlhaines@umich.edu
# From: bkirschn@umich.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: zqian@umich.edu
# From: bkirschn@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: bkirschn@umich.edu
# From: bkirschn@umich.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: bkirschn@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: dlhaines@umich.edu
# From: josrodri@iupui.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: hu2@iupui.edu
# From: louis@media.berkeley.edu
# From: bkirschn@umich.edu
# From: josrodri@iupui.edu
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: josrodri@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: hu2@iupui.edu
# From: cwen@iupui.edu
# From: tnguyen@iupui.edu
# From: sgithens@caret.cam.ac.uk
# From: arwhyte@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: david.horwitz@uct.ac.za
# From: josrodri@iupui.edu
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: david.horwitz@uct.ac.za
# From: dlhaines@umich.edu
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: gbhatnag@umich.edu
# From: dlhaines@umich.edu
# From: jimeng@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: rjlowe@iupui.edu
# From: jimeng@umich.edu
# From: wagnermr@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: wagnermr@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %%
# Reviewed: 
# .rstrip() removes the trailing characters
# re is the regular expression library
# .search() takes two arguments
# first = what are you looking for
# second = where do you want to be looking
# if it's true (finds a match), then print(line) 

import re
hand = open('mbox-short.txt') 
for line in hand: 
    line = line.rstrip() 
    if re.search('^From:', line): 
        print(line)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: mmmay@indiana.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: gopal.ramasammycook@gmail.com
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: stuart.freeman@et.gatech.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: wagnermr@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: tnguyen@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: wagnermr@iupui.edu
# From: gopal.ramasammycook@gmail.com
# From: ray@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: zqian@umich.edu
# From: wagnermr@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: chmaurer@iupui.edu
# From: stuart.freeman@et.gatech.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: rjlowe@iupui.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: aaronz@vt.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: ian@caret.cam.ac.uk
# From: ian@caret.cam.ac.uk
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: wagnermr@iupui.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: rjlowe@iupui.edu
# From: jimeng@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: gsilver@umich.edu
# From: ian@caret.cam.ac.uk
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: josrodri@iupui.edu
# From: josrodri@iupui.edu
# From: csev@umich.edu
# From: ian@caret.cam.ac.uk
# From: csev@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: knoop@umich.edu
# From: cwen@iupui.edu
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: csev@umich.edu
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: bkirschn@umich.edu
# From: jimeng@umich.edu
# From: ian@caret.cam.ac.uk
# From: stephen.marquard@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: ian@caret.cam.ac.uk
# From: jimeng@umich.edu
# From: jimeng@umich.edu
# From: ray@media.berkeley.edu
# From: ian@caret.cam.ac.uk
# From: ian@caret.cam.ac.uk
# From: stuart.freeman@et.gatech.edu
# From: bkirschn@umich.edu
# From: zqian@umich.edu
# From: louis@media.berkeley.edu
# From: dlhaines@umich.edu
# From: bkirschn@umich.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: zqian@umich.edu
# From: bkirschn@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: bkirschn@umich.edu
# From: bkirschn@umich.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: bkirschn@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: dlhaines@umich.edu
# From: josrodri@iupui.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: dlhaines@umich.edu
# From: hu2@iupui.edu
# From: louis@media.berkeley.edu
# From: bkirschn@umich.edu
# From: josrodri@iupui.edu
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: josrodri@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: hu2@iupui.edu
# From: cwen@iupui.edu
# From: tnguyen@iupui.edu
# From: sgithens@caret.cam.ac.uk
# From: arwhyte@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: david.horwitz@uct.ac.za
# From: josrodri@iupui.edu
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: sgithens@caret.cam.ac.uk
# From: david.horwitz@uct.ac.za
# From: dlhaines@umich.edu
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: gbhatnag@umich.edu
# From: dlhaines@umich.edu
# From: jimeng@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: rjlowe@iupui.edu
# From: jimeng@umich.edu
# From: wagnermr@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: wagnermr@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %%
import re
s = 'A message from skim@harvard.edu to jyum@brown.edu about meeting @2pm'
lst = re.findall('\S+@\S+',s) 
print(lst)

# The findall() method searches the string in the second argument... 
# and returns a list of all of the strings that look like email addresses
# \S => non-whitespace character
# Out:
# ['skim@harvard.edu', 'jyum@brown.edu']

# %%
# notice @2pm is not taken
# notice that @edu is not taken
# but b@i is taken because it's looking for at least one non-whitespace character! 

s = 'skim@harvard.edu to jyum@brown.edu about meeting @2pm but not from @com or ai@ but we taken b@i'
lst = re.findall('\S+@\S+',s) 
print(lst)
# Out:
# ['skim@harvard.edu', 'jyum@brown.edu', 'b@i']

# %%
hand = open('mbox-short.txt')
for line in hand: 
    line = line.rstrip()
    x = re.findall('\S+@\S+', line) 
    if len(x) > 0: 
        print(x) 
        
# Why do we need another variable x? 
# ANS: it makes the code much clearer
# Out:
# ['stephen.marquard@uct.ac.za']
# ['<postmaster@collab.sakaiproject.org>']
# ['<200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>']
# ['<source@collab.sakaiproject.org>;']
# ['<source@collab.sakaiproject.org>;']
# ['<source@collab.sakaiproject.org>;']
# ['apache@localhost)']
# ['source@collab.sakaiproject.org;']
# ['stephen.marquard@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['stephen.marquard@uct.ac.za']
# ['louis@media.berkeley.edu']
# ['<postmaster@collab.sakaiproject.org>']
# ['<200801042308.m04N8v6O008125@nakamura.uits.iupui.edu>']
# ['<source@collab.sakaiproject.org>;']
# ['<source@collab.sakaiproject.org>;']
# ['<source@collab.sakaiproject.org>;']
# ['apache@localhost)']
# ['source@collab.sakaiproject.org;']
# ['louis@media.berkeley.edu']
# ['source@collab.sakaiproject.org']
# ['louis@media.berkeley.edu']
# ['louis@media.berkeley.edu']
# ['zqian@umich.edu']
# ['<postmaster@collab.sakaiproject.org>']
# ['<200801
nakamura.uits.iupui.edu>']
# ['<source@collab.sakaiproject.org>;']
# ['<source@collab.sakaiproject.org>;']
# ['<source@collab.sakaiproject.org>;']
# ['apache@localhost)']
# ['source@collab.sakaiproject.org;']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']

# %%
# you can see from the example above that ... there's some issues 
# The email addresses are pulling in values that include the ">" characters
# and there are also ";" getting pulled in. This is wrong. 
# big picture: the motif here is that we're looking to pull in 
# a specific value from the document, in this case the email addresses
# if we wanted to find a line where a word appeared we'd run the .search()

# Use [a-zA-Z0-9]\S*@\S*[a-zA-Z] 

# translation:
# [a-zA-Z0-9] => substrings that start with a single lowercase letter,
# uppercase letter, or a number... followed by a number

# \S*@\S* => 0 or more non-blank characters followed by an at-sign
# followed by zero or more non-blank characters (\S*)
# notice we switched from + to * to indicate zero or more non-blank 
# since [a-zA-Z0-9] is already one non-blank character

# [a-zA-Z] demands that the regular expression parser finds a string
# that must end with a letter

import re 
hand = open('mbox-short.txt') 
for line in hand: 
    line = line.rstrip()
    x = re.findall('[a-zA-Z0-9]\S+@\S+[a-zA-Z]', line) 
    if len(x) > 0: 
        print(x)
# Out:
# ['stephen.marquard@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200801051412.m05ECIaH010327@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['stephen.marquard@uct.ac.za']
# ['louis@media.berkeley.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801042308.m04N8v6O008125@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['louis@media.berkeley.edu']
# ['source@collab.sakaiproject.org']
# ['louis@media.berkeley.edu']
# ['louis@media.berkeley.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801042109.m04L92hb007923@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['rjlowe@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801042044.m04Kiem3007881@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['rjlowe@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['rjlowe@iupui.edu']
# ['rjlowe@iupui.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801042001.m04K1cO0007738@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['rjlowe@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801041948.m04JmdwO007705@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['rjlowe@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['rjlowe@iupui.edu']
# ['rjlowe@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801041635.m04GZQGZ007313@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['hu2@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801041633.m04GX6eG007292@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['hu2@iupui.edu']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801041611.m04GB1Lb007221@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801041610.m04GA5KP007209@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801041609.m04G9EuX007197@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801041608.m04G8d7w007184@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['wagnermr@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801041537.m04Fb6Ci007092@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['wagnermr@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['wagnermr@iupui.edu']
# ['wagnermr@iupui.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801041515.m04FFv42007050@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['antranig@caret.cam.ac.uk']
# ['postmaster@collab.sakaiproject.org']
# ['200801041502.m04F21Jo007031@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['antranig@caret.cam.ac.uk']
# ['source@collab.sakaiproject.org']
# ['antranig@caret.cam.ac.uk']
# ['antranig@caret.cam.ac.uk']
# ['gopal.ramasammycook@gmail.com']
# ['postmaster@collab.sakaiproject.org']
# ['200801041403.m04E3psW006926@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gopal.ramasammycook@gmail.com']
# ['source@collab.sakaiproject.org']
# ['gopal.ramasammycook@gmail.com']
# ['gopal.ramasammycook@gmail.com']
# ['david.horwitz@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200801041200.m04C0gfK006793@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x']
# ['dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x']
# ['david.horwitz@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200801041106.m04B6lK3006677@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200801040947.m049lUxo006517@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['josrodri@iupui.edu']
# ['dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x']
# ['david.horwitz@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200801040932.m049W2i5006493@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['josrodri@iupui.edu']
# ['dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x']
# ['stephen.marquard@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200801040905.m0495rWB006420@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['stephen.marquard@uct.ac.za']
# ['louis@media.berkeley.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801040023.m040NpCc005473@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['louis@media.berkeley.edu']
# ['source@collab.sakaiproject.org']
# ['louis@media.berkeley.edu']
# ['louis@media.berkeley.edu']
# ['louis@media.berkeley.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801032216.m03MGhDa005292@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['louis@media.berkeley.edu']
# ['source@collab.sakaiproject.org']
# ['louis@media.berkeley.edu']
# ['louis@media.berkeley.edu']
# ['ray@media.berkeley.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801032205.m03M5Ea7005273@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['ray@media.berkeley.edu']
# ['source@collab.sakaiproject.org']
# ['ray@media.berkeley.edu']
# ['ray@media.berkeley.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801032133.m03LX3gG005191@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801032127.m03LRUqH005177@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['wagnermr@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801032122.m03LMFo4005148@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['wagnermr@iupui.edu']
# ['ray@media.berkeley.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801032054.m03KsIIF005054@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['ray@media.berkeley.edu']
# ['source@collab.sakaiproject.org']
# ['ray@media.berkeley.edu']
# ['ray@media.berkeley.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801032052.m03KqOsp005029@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801032025.m03KPvQi004928@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801032024.m03KOBAp004915@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['wagnermr@iupui.edu']
# ['rjlowe@iupui.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801032022.m03KMFfc004903@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031930.m03JUkCZ004841@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031849.m03InajQ004753@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['mmmay@indiana.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031837.m03IbPY7004727@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['mmmay@indiana.edu']
# ['source@collab.sakaiproject.org']
# ['mmmay@indiana.edu']
# ['mmmay@indiana.edu']
# ['wagnermr@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031819.m03IJA7j004645@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031815.m03IFbue004618@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031812.m03ICrFH004606@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031807.m03I7eg2004582@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031806.m03I6g8Y004558@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031806.m03I6pEt004570@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031804.m03I4lVU004546@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['ray@media.berkeley.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031747.m03HlB1h004532@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['ray@media.berkeley.edu']
# ['source@collab.sakaiproject.org']
# ['ray@media.berkeley.edu']
# ['ray@media.berkeley.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031730.m03HUeEg004479@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031726.m03HQUQ6004462@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031723.m03HNIp2004441@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031643.m03Gh1r2004386@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031627.m03GR5UM004357@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['gopal.ramasammycook@gmail.com']
# ['postmaster@collab.sakaiproject.org']
# ['200801031610.m03GAkl3004326@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gopal.ramasammycook@gmail.com']
# ['source@collab.sakaiproject.org']
# ['gopal.ramasammycook@gmail.com']
# ['gopal.ramasammycook@gmail.com']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031528.m03FSpXg004260@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031526.m03FQhmF004248@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['stuart.freeman@et.gatech.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031521.m03FLXtP004230@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['stuart.freeman@et.gatech.edu']
# ['source@collab.sakaiproject.org']
# ['stuart.freeman@et.gatech.edu']
# ['stuart.freeman@et.gatech.edu']
# ['stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls']
# ['stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls']
# ['david.horwitz@uct.ac.za']
# ['stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls']
# ['stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls']
# ['david.horwitz@uct.ac.za']
# ['stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls']
# ['stuart@mothra:pts/2)----------------------------------------------------------------------(/home/stuart/src/sakai_2-4-x/polls']
# ['david.horwitz@uct.ac.za']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031519.m03FJsfm004218@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031506.m03F6Ctn004182@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031505.m03F534R004169@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031503.m03F3cRt004144@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031501.m03F11ZP004123@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['wagnermr@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031429.m03ETqAT004022@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['wagnermr@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['wagnermr@iupui.edu']
# ['wagnermr@iupui.edu']
# ['stuart.freeman@et.gatech.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031423.m03ENc58004008@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['stuart.freeman@et.gatech.edu']
# ['source@collab.sakaiproject.org']
# ['stuart.freeman@et.gatech.edu']
# ['stuart.freeman@et.gatech.edu']
# ['stuart@mothra:pts/2)--------------------------------------------------(/home/stuart/src/sakai_2-4-x/reference/docs/conversion']
# ['stuart@mothra:pts/2)--------------------------------------------------(/home/stuart/src/sakai_2-4-x/reference/docs/conversion']
# ['stuart@mothra:pts/2)--------------------------------------------------(/home/stuart/src/sakai_2-4-x/reference/docs/conversion']
# ['stuart@mothra:pts/2)--------------------------------------------------(/home/stuart/src/sakai_2-4-x/reference/docs/conversion']
# ['cwen@iupui.edu']
# ['tnguyen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200801031420.m03EKxOB003996@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# 
nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['sgithens@caret.cam.ac.uk']
# ['source@collab.sakaiproject.org']
# ['sgithens@caret.cam.ac.uk']
# ['sgithens@caret.cam.ac.uk']
# ['sgithens@caret.cam.ac.uk']
# ['postmaster@collab.sakaiproject.org']
# ['200712201410.lBKEAVvU006730@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['sgithens@caret.cam.ac.uk']
# ['source@collab.sakaiproject.org']
# ['sgithens@caret.cam.ac.uk']
# ['sgithens@caret.cam.ac.uk']
# ['sgithens@caret.cam.ac.uk']
# ['postmaster@collab.sakaiproject.org']
# ['200712201404.lBKE4JLD006714@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['sgithens@caret.cam.ac.uk']
# ['source@collab.sakaiproject.org']
# ['sgithens@caret.cam.ac.uk']
# ['sgithens@caret.cam.ac.uk']
# ['david.horwitz@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200712201259.lBKCx2DB006645@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x']
# ['dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x']
# ['dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x']
# ['dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x']
# ['dlhaines@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712201238.lBKCc5J1006626@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['dlhaines@umich.edu']
# ['source@collab.sakaiproject.org']
# ['dlhaines@umich.edu']
# ['dlhaines@umich.edu']
# ['stephen.marquard@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200712201142.lBKBgr2P006558@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['stephen.marquard@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200712201048.lBKAm7bk006486@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['dhorwitz@david-horwitz-6:~/branchManagemnt/sakai_2-5-x']
# ['david.horwitz@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200712201038.lBKAcvpm006474@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['stephen.marquard@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200712200922.lBK9M5uO006414@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['stephen.marquard@uct.ac.za']
# ['stephen.marquard@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200712200918.lBK9IlJJ006402@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['stephen.marquard@uct.ac.za']
# ['stephen.marquard@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200712200913.lBK9D1D7006390@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['postmaster@collab.sakaiproject.org']
# ['200712200858.lBK8wHWR005906@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['source@collab.sakaiproject.org']
# ['david.horwitz@uct.ac.za']
# ['david.horwitz@uct.ac.za']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712200323.lBK3NbbE005769@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712200319.lBK3JMgx005757@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['source@collab.sakaiproject.org']
# ['zqian@umich.edu']
# ['zqian@umich.edu']
# ['gbhatnag@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712200309.lBK39mSv005692@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gbhatnag@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gbhatnag@umich.edu']
# ['gbhatnag@umich.edu']
# ['dlhaines@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712200106.lBK160mp005608@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['dlhaines@umich.edu']
# ['source@collab.sakaiproject.org']
# ['dlhaines@umich.edu']
# ['dlhaines@umich.edu']
# ['jimeng@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192324.lBJNOUcI005472@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['jimeng@umich.edu']
# ['source@collab.sakaiproject.org']
# ['jimeng@umich.edu']
# ['jimeng@umich.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192220.lBJMKnid005430@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192216.lBJMGgxo005417@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192156.lBJLuYiD005370@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192154.lBJLsnkN005358@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192153.lBJLrZ5W005346@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['ray@media.berkeley.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192152.lBJLqDXl005334@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['ray@media.berkeley.edu']
# ['source@collab.sakaiproject.org']
# ['ray@media.berkeley.edu']
# ['ray@media.berkeley.edu']
# ['rjlowe@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192148.lBJLmKnH005306@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['rjlowe@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['rjlowe@iupui.edu']
# ['rjlowe@iupui.edu']
# ['jimeng@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192137.lBJLb8VF005274@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['jimeng@umich.edu']
# ['source@collab.sakaiproject.org']
# ['jimeng@umich.edu']
# ['jimeng@umich.edu']
# ['wagnermr@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192121.lBJLLnS4005240@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['wagnermr@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['wagnermr@iupui.edu']
# ['wagnermr@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192048.lBJKmCfO005175@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192044.lBJKiibw005162@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['wagnermr@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192039.lBJKdMnj005150@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['wagnermr@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['wagnermr@iupui.edu']
# ['wagnermr@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712192017.lBJKHKBt005108@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712191947.lBJJllbN005040@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712191947.lBJJlLbV005028@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712191935.lBJJZ4VK004956@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['source@collab.sakaiproject.org']
# ['gsilver@umich.edu']
# ['gsilver@umich.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712191924.lBJJOXiR004942@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712191850.lBJIoQjl004892@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']
# ['postmaster@collab.sakaiproject.org']
# ['200712191911.lBJJBYa1004930@nakamura.uits.iupui.edu']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['source@collab.sakaiproject.org']
# ['apache@localhost']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['source@collab.sakaiproject.org']
# ['cwen@iupui.edu']
# ['cwen@iupui.edu']

# %%
# Aside: just a stupid example 

# we could use re.findall() to pull entire lines 
# but it's awkward and not clean in what it's doing... 

import re
hand = open('mbox-short.txt') 
for line in hand: 
    line = line.rstrip()
    murder = re.findall('murder',line)
    if len(murder) > 0: # so if you've found it 
        print(line) 
        

## A much better way is to simply run a search on the line 
# instead of using the re.findall
# re.findall() is more to extract out the value we care about 

import re
hand = open('mbox-short.txt') 
for line in hand: 
    line = line.rstrip() 
    if re.search('murder', line): 
        print(line)
# Out:
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.97])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.46])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.90])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.95])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.96])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.92])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.25])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.39])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.98])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.91])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.36])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.34])
# Received: from murder ([unix socket])
# Received: from murder (mail.umich.edu [141.211.14.93])
# Received: from murder ([unix socket])

# %%
import re
hand = open('mbox-short.txt') 
for line in hand: 
    line = line.rstrip()
    if re.search('^X\S*: [0-9.]+', line): 
        print(line) 
        
# notice th \S* is used to denote "or more" 
# The [0-9.]+ refers to a digit (0-9) or a period.. 
# inside of the [ ... ] the period matches an actual period and 
# doesn't denote a wildcard between the square brackets
# what it's trying to do is capture a number even if that number is a 
# decimal (aka has a period!)
# Out:
# X-DSPAM-Confidence: 0.8475
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6178
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6961
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7565
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7626
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7556
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7002
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7615
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7601
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7605
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6959
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7606
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7559
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7605
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6932
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7558
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6526
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6948
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6528
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7002
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7554
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6956
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6959
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7556
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9846
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8509
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9907
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7003
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8507
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9895
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9965
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9875
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9867
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9903
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7006
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9907
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9886
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8495
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7606
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9875
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8489
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9854
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7549
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9877
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9881
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9864
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9870
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8493
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9837
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8479
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9852
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9928
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9898
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9855
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8484
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9856
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9892
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8484
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8518
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8483
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8524
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9879
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9843
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7568
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7568
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7619
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9871
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8525
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8477
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9947
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9832
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8504
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9864
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9842
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8500
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8462
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9860
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9842
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7622
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9865
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8500
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8479
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9865
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9852
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9856
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8519
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8514
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8511
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9843
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8505
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7625
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8524
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7623
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8509
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9844
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8472
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9823
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8489
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6999
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9872
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8501
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9897
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9887
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9866
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8473
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9847
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8489
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9830
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.5435
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9779
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8508
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.5933
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6517
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8487
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9852
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6186
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6567
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.5304
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8479
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7608
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.5717
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8464
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7599
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7610
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9865
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9776
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9776
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9797
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9776
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9793
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9857
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8480
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9857
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8504
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9863
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6198
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7604
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7613
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7568
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8494
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8494
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8483
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9881
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7564
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8431
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9812
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9832
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9885
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9854
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7597
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6948
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.5715
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9869
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8494
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9866
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6948
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6957
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8482
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7602
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7605
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9877
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9872
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9834
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9856
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9859
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9870
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9848
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9836
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9892
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9894
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9816
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9858
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8493
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9879
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8470
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8475
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9836
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9845
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9907
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9883
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9874
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8502
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9843
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8469
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8470
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9831
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9820
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9851
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8441
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9859
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9840
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9817
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9829
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6940
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9838
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9816
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6954
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9829
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9776
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9762
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9799
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9812
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9804
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8425
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8418
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8466
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9804
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9796
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9780
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9861
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9799
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9812
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9808
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9799
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9832
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9758
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9842
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9770
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9776
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9794
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9785
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9773
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9785
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9813
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9785
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9774
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8418
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9779
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9789
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8413
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9787
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9777
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9787
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9851
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9889
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9839
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7541
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8434
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8418
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9844
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9834
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9819
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9843
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9881
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9832
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9876
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9853
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9845
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9818
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9829
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9825
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9824
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9838
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7604
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9825
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8495
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8471
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9817
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9805
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9817
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9848
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6962
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6510
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7602
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8469
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.9830
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.8477
# X-DSPAM-Probability: 0.0000

# %%
# Now we want to extract the numbers... 
# First, do it with split() 
testSTR = "the cat was in the tree." 

# Now extract the last part... 
# Get the last part len(testSTR.split())
# testSTR.split()[LAST PART INDEX - 1] 
last_word = testSTR.split()[len(testSTR.split())-1]
print(last_word[:-1]) # removes the period (the last character)
# Out:
# tree

# %%
# Now try to extract it using a regular expression..
import re 

x = re.findall('tree', testSTR) 
print(x)
# Out:
# ['tree']

# %%
import re 
hand = open('mbox-short.txt') 
for line in hand: 
    line = line.rstrip() 
    x = re.findall('^X\S*: ([0-9.]+)', line)
    if len(x) > 0: 
        print(x) 
        
# so what's going on here ... 
# THE KEY difference is that we are using the PARENTHESIS
# The parenthesis tell the computer to return the floating-point number
# portion of the matching string!! 


# Compare to: re.search('^X\S*: [0-9.]+', line): 
# the small difference is the use of parenthesis! 
# and of course the use of re.findall() instead of re.search()
# Out:
# ['0.8475']
# ['0.0000']
# ['0.6178']
# ['0.0000']
# ['0.6961']
# ['0.0000']
# ['0.7565']
# ['0.0000']
# ['0.7626']
# ['0.0000']
# ['0.7556']
# ['0.0000']
# ['0.7002']
# ['0.0000']
# ['0.7615']
# ['0.0000']
# ['0.7601']
# ['0.0000']
# ['0.7605']
# ['0.0000']
# ['0.6959']
# ['0.0000']
# ['0.7606']
# ['0.0000']
# ['0.7559']
# ['0.0000']
# ['0.7605']
# ['0.0000']
# ['0.6932']
# ['0.0000']
# ['0.7558']
# ['0.0000']
# ['0.6526']
# ['0.0000']
# ['0.6948']
# ['0.0000']
# ['0.6528']
# ['0.0000']
# ['0.7002']
# ['0.0000']
# ['0.7554']
# ['0.0000']
# ['0.6956']
# ['0.0000']
# ['0.6959']
# ['0.0000']
# ['0.7556']
# ['0.0000']
# ['0.9846']
# ['0.0000']
# ['0.8509']
# ['0.0000']
# ['0.9907']
# ['0.0000']
# ['0.7003']
# ['0.0000']
# ['0.8507']
# ['0.0000']
# ['0.9895']
# ['0.0000']
# ['0.9965']
# ['0.0000']
# ['0.9875']
# ['0.0000']
# ['0.9867']
# ['0.0000']
# ['0.9903']
# ['0.0000']
# ['0.7006']
# ['0.0000']
# ['0.9907']
# ['0.0000']
# ['0.9886']
# ['0.0000']
# ['0.8495']
# ['0.0000']
# ['0.7606']
# ['0.0000']
# ['0.9875']
# ['0.0000']
# ['0.8489']
# ['0.0000']
# ['0.9854']
# ['0.0000']
# ['0.7549']
# ['0.0000']
# ['0.9877']
# ['0.0000']
# ['0.9881']
# ['0.0000']
# ['0.9864']
# ['0.0000']
# ['0.9870']
# ['0.0000']
# ['0.8493']
# ['0.0000']
# ['0.9837']
# ['0.0000']
# ['0.8479']
# ['0.0000']
# ['0.9852']
# ['0.0000']
# ['0.9928']
# ['0.0000']
# ['0.9898']
# ['0.0000']
# ['0.9855']
# ['0.0000']
# ['0.8484']
# ['0.0000']
# ['0.9856']
# ['0.0000']
# ['0.9892']
# ['0.0000']
# ['0.8484']
# ['0.0000']
# ['0.8518']
# ['0.0000']
# ['0.8483']
# ['0.0000']
# ['0.8524']
# ['0.0000']
# ['0.9879']
# ['0.0000']
# ['0.9843']
# ['0.0000']
# ['0.7568']
# ['0.0000']
# ['0.7568']
# ['0.0000']
# ['0.7619']
# ['0.0000']
# ['0.9871']
# ['0.0000']
# ['0.8525']
# ['0.0000']
# ['0.8477']
# ['0.0000']
# ['0.9947']
# ['0.0000']
# ['0.9832']
# ['0.0000']
# ['0.8504']
# ['0.0000']
# ['0.9864']
# ['0.0000']
# ['0.9842']
# ['0.0000']
# ['0.8500']
# ['0.0000']
# ['0.8462']
# ['0.0000']
# ['0.9860']
# ['0.0000']
# ['0.9842']
# ['0.0000']
# ['0.7622']
# ['0.0000']
# ['0.9865']
# ['0.0000']
# ['0.8500']
# ['0.0000']
# ['0.8479']
# ['0.0000']
# ['0.9865']
# ['0.0000']
# ['0.9852']
# ['0.0000']
# ['0.9856']
# ['0.0000']
# ['0.8519']
# ['0.0000']
# ['0.8514']
# ['0.0000']
# ['0.8511']
# ['0.0000']
# ['0.9843']
# ['0.0000']
# ['0.8505']
# ['0.0000']
# ['0.7625']
# ['0.0000']
# ['0.8524']
# ['0.0000']
# ['0.7623']
# ['0.0000']
# ['0.8509']
# ['0.0000']
# ['0.9844']
# ['0.0000']
# ['0.8472']
# ['0.0000']
# ['0.9823']
# ['0.0000']
# ['0.8489']
# ['0.0000']
# ['0.6999']
# ['0.0000']
# ['0.9872']
# ['0.0000']
# ['0.8501']
# ['0.0000']
# ['0.9897']
# ['0.0000']
# ['0.9887']
# ['0.0000']
# ['0.9866']
# ['0.0000']
# ['0.8473']
# ['0.0000']
# ['0.9847']
# ['0.0000']
# ['0.8489']
# ['0.0000']
# ['0.9830']
# ['0.0000']
# ['0.5435']
# ['0.0000']
# ['0.9779']
# ['0.0000']
# ['0.8508']
# ['0.0000']
# ['0.5933']
# ['0.0000']
# ['0.6517']
# ['0.0000']
# ['0.8487']
# ['0.0000']
# ['0.9852']
# ['0.0000']
# ['0.6186']
# ['0.0000']
# ['0.6567']
# ['0.0000']
# ['0.5304']
# ['0.0000']
# ['0.8479']
# ['0.0000']
# ['0.7608']
# ['0.0000']
# ['0.5717']
# ['0.0000']
# ['0.8464']
# ['0.0000']
# ['0.7599']
# ['0.0000']
# ['0.7610']
# ['0.0000']
# ['0.9865']
# ['0.0000']
# ['0.9776']
# ['0.0000']
# ['0.9776']
# ['0.0000']
# ['0.9797']
# ['0.0000']
# ['0.9776']
# ['0.0000']
# ['0.9793']
# ['0.0000']
# ['0.9857']
# ['0.0000']
# ['0.8480']
# ['0.0000']
# ['0.9857']
# ['0.0000']
# ['0.8504']
# ['0.0000']
# ['0.9863']
# ['0.0000']
# ['0.6198']
# ['0.0000']
# ['0.7604']
# ['0.0000']
# ['0.7613']
# ['0.0000']
# ['0.7568']
# ['0.0000']
# ['0.8494']
# ['0.0000']
# ['0.8494']
# ['0.0000']
# ['0.8483']
# ['0.0000']
# ['0.9881']
# ['0.0000']
# ['0.7564']
# ['0.0000']
# ['0.8431']
# ['0.0000']
# ['0.9812']
# ['0.0000']
# ['0.9832']
# ['0.0000']
# ['0.9885']
# ['0.0000']
# ['0.9854']
# ['0.0000']
# ['0.7597']
# ['0.0000']
# ['0.6948']
# ['0.0000']
# ['0.5715']
# ['0.0000']
# ['0.9869']
# ['0.0000']
# ['0.8494']
# ['0.0000']
# ['0.9866']
# ['0.0000']
# ['0.6948']
# ['0.0000']
# ['0.6957']
# ['0.0000']
# ['0.8482']
# ['0.0000']
# ['0.7602']
# ['0.0000']
# ['0.7605']
# ['0.0000']
# ['0.9877']
# ['0.0000']
# ['0.9872']
# ['0.0000']
# ['0.9834']
# ['0.0000']
# ['0.9856']
# ['0.0000']
# ['0.9859']
# ['0.0000']
# ['0.9870']
# ['0.0000']
# ['0.9848']
# ['0.0000']
# ['0.9836']
# ['0.0000']
# ['0.9892']
# ['0.0000']
# ['0.9894']
# ['0.0000']
# ['0.9816']
# ['0.0000']
# ['0.9858']
# ['0.0000']
# ['0.8493']
# ['0.0000']
# ['0.9879']
# ['0.0000']
# ['0.8470']
# ['0.0000']
# ['0.8475']
# ['0.0000']
# ['0.9836']
# ['0.0000']
# ['0.9845']
# ['0.0000']
# ['0.9907']
# ['0.0000']
# ['0.9883']
# ['0.0000']
# ['0.9874']
# ['0.0000']
# ['0.8502']
# ['0.0000']
# ['0.9843']
# ['0.0000']
# ['0.8469']
# ['0.0000']
# ['0.8470']
# ['0.0000']
# ['0.9831']
# ['0.0000']
# ['0.9820']
# ['0.0000']
# ['0.9851']
# ['0.0000']
# ['0.8441']
# ['0.0000']
# ['0.9859']
# ['0.0000']
# ['0.9840']
# ['0.0000']
# ['0.9817']
# ['0.0000']
# ['0.9829']
# ['0.0000']
# ['0.6940']
# ['0.0000']
# ['0.9838']
# ['0.0000']
# ['0.9816']
# ['0.0000']
# ['0.6954']
# ['0.0000']
# ['0.9829']
# ['0.0000']
# ['0.9776']
# ['0.0000']
# ['0.9762']
# ['0.0000']
# ['0.9799']
# ['0.0000']
# ['0.9812']
# ['0.0000']
# ['0.9804']
# ['0.0000']
# ['0.8425']
# ['0.0000']
# ['0.8418']
# ['0.0000']
# ['0.8466']
# ['0.0000']
# ['0.9804']
# ['0.0000']
# ['0.9796']
# ['0.0000']
# ['0.9780']
# ['0.0000']
# ['0.9861']
# ['0.0000']
# ['0.9799']
# ['0.0000']
# ['0.9812']
# ['0.0000']
# ['0.9808']
# ['0.0000']
# ['0.9799']
# ['0.0000']
# ['0.9832']
# ['0.0000']
# ['0.9758']
# ['0.0000']
# ['0.9842']
# ['0.0000']
# ['0.9770']
# ['0.0000']
# ['0.9776']
# ['0.0000']
# ['0.9794']
# ['0.0000']
# ['0.9785']
# ['0.0000']
# ['0.9773']
# ['0.0000']
# ['0.9785']
# ['0.0000']
# ['0.9813']
# ['0.0000']
# ['0.9785']
# ['0.0000']
# ['0.9774']
# ['0.0000']
# ['0.8418']
# ['0.0000']
# ['0.9779']
# ['0.0000']
# ['0.9789']
# ['0.0000']
# ['0.8413']
# ['0.0000']
# ['0.9787']
# ['0.0000']
# ['0.9777']
# ['0.0000']
# ['0.9787']
# ['0.0000']
# ['0.9851']
# ['0.0000']
# ['0.9889']
# ['0.0000']
# ['0.9839']
# ['0.0000']
# ['0.7541']
# ['0.0000']
# ['0.8434']
# ['0.0000']
# ['0.8418']
# ['0.0000']
# ['0.9844']
# ['0.0000']
# ['0.9834']
# ['0.0000']
# ['0.9819']
# ['0.0000']
# ['0.9843']
# ['0.0000']
# ['0.9881']
# ['0.0000']
# ['0.9832']
# ['0.0000']
# ['0.9876']
# ['0.0000']
# ['0.9853']
# ['0.0000']
# ['0.9845']
# ['0.0000']
# ['0.9818']
# ['0.0000']
# ['0.9829']
# ['0.0000']
# ['0.9825']
# ['0.0000']
# ['0.9824']
# ['0.0000']
# ['0.9838']
# ['0.0000']
# ['0.7604']
# ['0.0000']
# ['0.9825']
# ['0.0000']
# ['0.8495']
# ['0.0000']
# ['0.8471']
# ['0.0000']
# ['0.9817']
# ['0.0000']
# ['0.9805']
# ['0.0000']
# ['0.9817']
# ['0.0000']
# ['0.9848']
# ['0.0000']
# ['0.6962']
# ['0.0000']
# ['0.6510']
# ['0.0000']
# ['0.7602']
# ['0.0000']
# ['0.8469']
# ['0.0000']
# ['0.9830']
# ['0.0000']
# ['0.8477']
# ['0.0000']

# %%
# here we want to just extract the numbers... 
# Could you have used split? sure you could've ...

numeric_data = [] 

import re 
hand = open('mbox-short.txt') 
for line in hand: 
    line = line.rstrip() 
    if re.search('^X\S*: ([0-9.]+)', line):
        print(line.split()[1]) # this just prints it, doesn't store
        numeric_data.append(line.split()[1]) # this stores it
# Out:
# 0.8475
# 0.0000
# 0.6178
# 0.0000
# 0.6961
# 0.0000
# 0.7565
# 0.0000
# 0.7626
# 0.0000
# 0.7556
# 0.0000
# 0.7002
# 0.0000
# 0.7615
# 0.0000
# 0.7601
# 0.0000
# 0.7605
# 0.0000
# 0.6959
# 0.0000
# 0.7606
# 0.0000
# 0.7559
# 0.0000
# 0.7605
# 0.0000
# 0.6932
# 0.0000
# 0.7558
# 0.0000
# 0.6526
# 0.0000
# 0.6948
# 0.0000
# 0.6528
# 0.0000
# 0.7002
# 0.0000
# 0.8434
# 0.0000
# 0.8418
# 0.0000
# 0.9844
# 0.0000
# 0.9834
# 0.0000
# 0.9819
# 0.0000
# 0.9843
# 0.0000
# 0.9881
# 0.0000
# 0.9832
# 0.0000
# 0.9876
# 0.0000
# 0.9853
# 0.0000
# 0.9845
# 0.0000
# 0.9818
# 0.0000
# 0.9829
# 0.0000
# 0.9825
# 0.0000
# 0.9824
# 0.0000
# 0.9838
# 0.0000
# 0.7604
# 0.0000
# 0.9825
# 0.0000
# 0.8495
# 0.0000
# 0.8471
# 0.0000
# 0.9817
# 0.0000
# 0.9805
# 0.0000
# 0.9817
# 0.0000
# 0.9848
# 0.0000
# 0.6962
# 0.0000
# 0.6510
# 0.0000
# 0.7602
# 0.0000
# 0.8469
# 0.0000
# 0.9830
# 0.0000
# 0.8477
# 0.0000

# %%
for item in numeric_data: 
    print([item]) # a bit of a hack here
# Out:
# ['0.8475']
# ['0.0000']
# ['0.6178']
# ['0.0000']
# ['0.6961']
# ['0.0000']
# ['0.7565']
# ['0.0000']
# ['0.7626']
# ['0.0000']
# ['0.7556']
# ['0.0000']
# ['0.7002']
# ['0.0000']
# ['0.7615']
# ['0.0000']
# ['0.7601']
# ['0.0000']
# ['0.7605']
# ['0.0000']
# ['0.6959']
# ['0.0000']
# ['0.7606']
# ['0.0000']
# ['0.7559']
# ['0.0000']
# ['0.7605']
# ['0.0000']
# ['0.6932']
# ['0.0000']
# ['0.7558']
# ['0.0000']
# ['0.6526']
# ['0.0000']
# ['0.6948']
# ['0.0000']
# ['0.6528']
# ['0.0000']
# ['0.7002']
# ['0.0000']
# ['0.7554']
# ['0.0000']
# ['0.6956']
# ['0.0000']
# ['0.6959']
# ['0.0000']
# ['0.7556']
# ['0.0000']
# ['0.9846']
# ['0.0000']
# ['0.8509']
# ['0.0000']
# ['0.9907']
# ['0.0000']
# ['0.7003']
# ['0.0000']
# ['0.8507']
# ['0.0000']
# ['0.9895']
# ['0.0000']
# ['0.9965']
# ['0.0000']
# ['0.9875']
# ['0.0000']
# ['0.9867']
# ['0.0000']
# ['0.9903']
# ['0.0000']
# ['0.7006']
# ['0.0000']
# ['0.9907']
# ['0.0000']
# ['0.9886']
# ['0.0000']
# ['0.8495']
# ['0.0000']
# ['0.7606']
# ['0.0000']
# ['0.9875']
# ['0.0000']
# ['0.8489']
# ['0.0000']
# ['0.9854']
# ['0.0000']
# ['0.7549']
# ['0.0000']
# ['0.9877']
# ['0.0000']
# ['0.9881']
# ['0.0000']
# ['0.9864']
# ['0.0000']
# ['0.9870']
# ['0.0000']
# ['0.8493']
# ['0.0000']
# ['0.9837']
# ['0.0000']
# ['0.8479']
# ['0.0000']
# ['0.9852']
# ['0.0000']
# ['0.9928']
# ['0.0000']
# ['0.9898']
# ['0.0000']
# ['0.9855']
# ['0.0000']
# ['0.8484']
# ['0.0000']
# ['0.9856']
# ['0.0000']
# ['0.9892']
# ['0.0000']
# ['0.8484']
# ['0.0000']
# ['0.8518']
# ['0.0000']
# ['0.8483']
# ['0.0000']
# ['0.8524']
# ['0.0000']
# ['0.9879']
# ['0.0000']
# ['0.9843']
# ['0.0000']
# ['0.7568']
# ['0.0000']
# ['0.7568']
# ['0.0000']
# ['0.7619']
# ['0.0000']
# ['0.9871']
# ['0.0000']
# ['0.8525']
# ['0.0000']
# ['0.8477']
# ['0.0000']
# ['0.9947']
# ['0.0000']
# ['0.9832']
# ['0.0000']
# ['0.8504']
# ['0.0000']
# ['0.9864']
# ['0.0000']
# ['0.9842']
# ['0.0000']
# ['0.8500']
# ['0.0000']
# ['0.8462']
# ['0.0000']
# ['0.9860']
# ['0.0000']
# ['0.9842']
# ['0.0000']
# ['0.7622']
# ['0.0000']
# ['0.9865']
# ['0.0000']
# ['0.8500']
# ['0.0000']
# ['0.8479']
# ['0.0000']
# ['0.9865']
# ['0.0000']
# ['0.9852']
# ['0.0000']
# ['0.9856']
# ['0.0000']
# ['0.8519']
# ['0.0000']
# ['0.8514']
# ['0.0000']
# ['0.8511']
# ['0.0000']
# ['0.9843']
# ['0.0000']
# ['0.8505']
# ['0.0000']
# ['0.7625']
# ['0.0000']
# ['0.8524']
# ['0.0000']
# ['0.7623']
# ['0.0000']
# ['0.8509']
# ['0.0000']
# ['0.9844']
# ['0.0000']
# ['0.8472']
# ['0.0000']
# ['0.9823']
# ['0.0000']
# ['0.8489']
# ['0.0000']
# ['0.6999']
# ['0.0000']
# ['0.9872']
# ['0.0000']
# ['0.8501']
# ['0.0000']
# ['0.9897']
# ['0.0000']
# ['0.9887']
# ['0.0000']
# ['0.9866']
# ['0.0000']
# ['0.8473']
# ['0.0000']
# ['0.9847']
# ['0.0000']
# ['0.8489']
# ['0.0000']
# ['0.9830']
# ['0.0000']
# ['0.5435']
# ['0.0000']
# ['0.9779']
# ['0.0000']
# ['0.8508']
# ['0.0000']
# ['0.5933']
# ['0.0000']
# ['0.6517']
# ['0.0000']
# ['0.8487']
# ['0.0000']
# ['0.9852']
# ['0.0000']
# ['0.6186']
# ['0.0000']
# ['0.6567']
# ['0.0000']
# ['0.5304']
# ['0.0000']
# ['0.8479']
# ['0.0000']
# ['0.7608']
# ['0.0000']
# ['0.5717']
# ['0.0000']
# ['0.8464']
# ['0.0000']
# ['0.7599']
# ['0.0000']
# ['0.7610']
# ['0.0000']
# ['0.9865']
# ['0.0000']
# ['0.9776']
# ['0.0000']
# ['0.9776']
# ['0.0000']
# ['0.9797']
# ['0.0000']
# ['0.9776']
# ['0.0000']
# ['0.9793']
# ['0.0000']
# ['0.9857']
# ['0.0000']
# ['0.8480']
# ['0.0000']
# ['0.9857']
# ['0.0000']
# ['0.8504']
# ['0.0000']
# ['0.9863']
# ['0.0000']
# ['0.6198']
# ['0.0000']
# ['0.7604']
# ['0.0000']
# ['0.7613']
# ['0.0000']
# ['0.7568']
# ['0.0000']
# ['0.8494']
# ['0.0000']
# ['0.8494']
# ['0.0000']
# ['0.8483']
# ['0.0000']
# ['0.9881']
# ['0.0000']
# ['0.7564']
# ['0.0000']
# ['0.8431']
# ['0.0000']
# ['0.9812']
# ['0.0000']
# ['0.9832']
# ['0.0000']
# ['0.9885']
# ['0.0000']
# ['0.9854']
# ['0.0000']
# ['0.7597']
# ['0.0000']
# ['0.6948']
# ['0.0000']
# ['0.5715']
# ['0.0000']
# ['0.9869']
# ['0.0000']
# ['0.8494']
# ['0.0000']
# ['0.9866']
# ['0.0000']
# ['0.6948']
# ['0.0000']
# ['0.6957']
# ['0.0000']
# ['0.8482']
# ['0.0000']
# ['0.7602']
# ['0.0000']
# ['0.7605']
# ['0.0000']
# ['0.9877']
# ['0.0000']
# ['0.9872']
# ['0.0000']
# ['0.9834']
# ['0.0000']
# ['0.9856']
# ['0.0000']
# ['0.9859']
# ['0.0000']
# ['0.9870']
# ['0.0000']
# ['0.9848']
# ['0.0000']
# ['0.9836']
# ['0.0000']
# ['0.9892']
# ['0.0000']
# ['0.9894']
# ['0.0000']
# ['0.9816']
# ['0.0000']
# ['0.9858']
# ['0.0000']
# ['0.8493']
# ['0.0000']
# ['0.9879']
# ['0.0000']
# ['0.8470']
# ['0.0000']
# ['0.8475']
# ['0.0000']
# ['0.9836']
# ['0.0000']
# ['0.9845']
# ['0.0000']
# ['0.9907']
# ['0.0000']
# ['0.9883']
# ['0.0000']
# ['0.9874']
# ['0.0000']
# ['0.8502']
# ['0.0000']
# ['0.9843']
# ['0.0000']
# ['0.8469']
# ['0.0000']
# ['0.8470']
# ['0.0000']
# ['0.9831']
# ['0.0000']
# ['0.9820']
# ['0.0000']
# ['0.9851']
# ['0.0000']
# ['0.8441']
# ['0.0000']
# ['0.9859']
# ['0.0000']
# ['0.9840']
# ['0.0000']
# ['0.9817']
# ['0.0000']
# ['0.9829']
# ['0.0000']
# ['0.6940']
# ['0.0000']
# ['0.9838']
# ['0.0000']
# ['0.9816']
# ['0.0000']
# ['0.6954']
# ['0.0000']
# ['0.9829']
# ['0.0000']
# ['0.9776']
# ['0.0000']
# ['0.9762']
# ['0.0000']
# ['0.9799']
# ['0.0000']
# ['0.9812']
# ['0.0000']
# ['0.9804']
# ['0.0000']
# ['0.8425']
# ['0.0000']
# ['0.8418']
# ['0.0000']
# ['0.8466']
# ['0.0000']
# ['0.9804']
# ['0.0000']
# ['0.9796']
# ['0.0000']
# ['0.9780']
# ['0.0000']
# ['0.9861']
# ['0.0000']
# ['0.9799']
# ['0.0000']
# ['0.9812']
# ['0.0000']
# ['0.9808']
# ['0.0000']
# ['0.9799']
# ['0.0000']
# ['0.9832']
# ['0.0000']
# ['0.9758']
# ['0.0000']
# ['0.9842']
# ['0.0000']
# ['0.9770']
# ['0.0000']
# ['0.9776']
# ['0.0000']
# ['0.9794']
# ['0.0000']
# ['0.9785']
# ['0.0000']
# ['0.9773']
# ['0.0000']
# ['0.9785']
# ['0.0000']
# ['0.9813']
# ['0.0000']
# ['0.9785']
# ['0.0000']
# ['0.9774']
# ['0.0000']
# ['0.8418']
# ['0.0000']
# ['0.9779']
# ['0.0000']
# ['0.9789']
# ['0.0000']
# ['0.8413']
# ['0.0000']
# ['0.9787']
# ['0.0000']
# ['0.9777']
# ['0.0000']
# ['0.9787']
# ['0.0000']
# ['0.9851']
# ['0.0000']
# ['0.9889']
# ['0.0000']
# ['0.9839']
# ['0.0000']
# ['0.7541']
# ['0.0000']
# ['0.8434']
# ['0.0000']
# ['0.8418']
# ['0.0000']
# ['0.9844']
# ['0.0000']
# ['0.9834']
# ['0.0000']
# ['0.9819']
# ['0.0000']
# ['0.9843']
# ['0.0000']
# ['0.9881']
# ['0.0000']
# ['0.9832']
# ['0.0000']
# ['0.9876']
# ['0.0000']
# ['0.9853']
# ['0.0000']
# ['0.9845']
# ['0.0000']
# ['0.9818']
# ['0.0000']
# ['0.9829']
# ['0.0000']
# ['0.9825']
# ['0.0000']
# ['0.9824']
# ['0.0000']
# ['0.9838']
# ['0.0000']
# ['0.7604']
# ['0.0000']
# ['0.9825']
# ['0.0000']
# ['0.8495']
# ['0.0000']
# ['0.8471']
# ['0.0000']
# ['0.9817']
# ['0.0000']
# ['0.9805']
# ['0.0000']
# ['0.9817']
# ['0.0000']
# ['0.9848']
# ['0.0000']
# ['0.6962']
# ['0.0000']
# ['0.6510']
# ['0.0000']
# ['0.7602']
# ['0.0000']
# ['0.8469']
# ['0.0000']
# ['0.9830']
# ['0.0000']
# ['0.8477']
# ['0.0000']

# %%
# returning back to this idea.. you can grab very specific values
# by leveraging on parenthesis with re.findall()

import re 
hand = open('mbox-short.txt')
for line in hand: 
    line = line.rstrip() 
    x = re.findall('^Details:.*rev=([0-9.]+)', line) 
    if len(x) > 0: 
        print(x)
# Out:
# ['39772']
# ['39771']
# ['39770']
# ['39769']
# ['39766']
# ['39765']
# ['39764']
# ['39763']
# ['39762']
# ['39761']
# ['39760']
# ['39759']
# ['39758']
# ['39757']
# ['39756']
# ['39755']
# ['39754']
# ['39753']
# ['39752']
# ['39751']
# ['39750']
# ['39749']
# ['39746']
# ['39745']
# ['39744']
# ['39743']
# ['39742']
# ['39741']
# ['39740']
# ['39739']
# ['39738']
# ['39737']
# ['39736']
# ['39735']
# ['39734']
# ['39733']
# ['39732']
# ['39731']
# ['39730']
# ['39728']
# ['39729']
# ['39727']
# ['39726']
# ['39725']
# ['39724']
# ['39723']
# ['39722']
# ['39721']
# ['39720']
# ['39719']
# ['39718']
# ['39717']
# ['39716']
# ['39715']
# ['39714']
# ['39713']
# ['39712']
# ['39711']
# ['39710']
# ['39709']
# ['39708']
# ['39707']
# ['39706']
# ['39697']
# ['39696']
# ['39695']
# ['39694']
# ['39692']
# ['39691']
# ['39690']
# ['39689']
# ['39688']
# ['39687']
# ['39686']
# ['39685']
# ['39684']
# ['39683']
# ['39682']
# ['39681']
# ['39680']
# ['39679']
# ['39678']
# ['39677']
# ['39676']
# ['39675']
# ['39674']
# ['39673']
# ['39672']
# ['39671']
# ['39670']
# ['39669']
# ['39668']
# ['39667']
# ['39666']
# ['44484']
# ['39665']
# ['39664']
# ['39663']
# ['39662']
# ['39660']
# ['39659']
# ['39658']
# ['39657']
# ['39656']
# ['39655']
# ['39654']
# ['39653']
# ['39652']
# ['39651']
# ['39650']
# ['39649']
# ['39648']
# ['39647']
# ['39646']
# ['39645']
# ['39644']
# ['39643']
# ['39642']
# ['39641']
# ['39640']
# ['39639']
# ['39638']
# ['39637']
# ['39636']
# ['39635']
# ['39634']
# ['39633']
# ['39632']
# ['39631']
# ['39630']
# ['39629']
# ['39628']
# ['39627']
# ['39626']
# ['39625']
# ['39624']
# ['39623']
# ['39622']
# ['39621']
# ['39620']
# ['39619']
# ['39618']
# ['39617']
# ['39616']
# ['39615']
# ['39614']
# ['39613']
# ['39611']
# ['39610']
# ['39609']
# ['39608']
# ['39607']
# ['39606']
# ['39605']
# ['39604']
# ['39603']
# ['39602']
# ['39601']
# ['39600']
# ['39599']
# ['39598']
# ['39597']
# ['39596']
# ['39595']
# ['39594']
# ['39593']
# ['39592']
# ['39591']
# ['39590']
# ['39589']
# ['39588']
# ['39587']
# ['39586']
# ['39585']
# ['39584']
# ['39583']
# ['39582']
# ['39581']
# ['39580']
# ['39579']
# ['39578']
# ['39577']
# ['39576']
# ['39575']
# ['39574']
# ['39573']
# ['39572']
# ['39571']
# ['39570']
# ['39569']
# ['39568']
# ['39567']
# ['39566']
# ['39565']
# ['39563']
# ['39564']
# ['39562']
# ['39561']
# ['39560']
# ['39559']
# ['39558']
# ['39557']
# ['39556']
# ['39555']
# ['39554']
# ['39553']
# ['39552']
# ['39551']
# ['39550']
# ['39549']
# ['39548']
# ['39547']
# ['39546']
# ['39545']
# ['39544']
# ['39543']
# ['39542']
# ['39541']
# ['39540']
# ['39539']
# ['39538']
# ['39537']
# ['39536']
# ['39535']
# ['39534']
# ['39533']
# ['39532']
# ['39531']
# ['39530']
# ['39529']
# ['39528']
# ['39527']
# ['39526']
# ['39525']
# ['39524']
# ['39523']
# ['39522']
# ['39521']
# ['39520']
# ['39519']
# ['39518']
# ['39517']
# ['39516']
# ['39515']
# ['39514']
# ['39513']
# ['39512']
# ['39511']
# ['39510']
# ['39509']
# ['39508']
# ['39507']
# ['39506']
# ['39505']
# ['39504']
# ['39503']
# ['39502']
# ['39501']
# ['39500']
# ['39499']
# ['39497']
# ['39498']

# %%
import re 
hand = open('mbox-short.txt')
for line in hand: 
    line = line.rstrip() 
    x = re.findall('^From .* ([0-9][0-9]):', line) 
    if len(x) > 0: print(x)
# Out:
# ['09']
# ['18']
# ['16']
# ['15']
# ['15']
# ['14']
# ['11']
# ['11']
# ['11']
# ['11']
# ['11']
# ['11']
# ['10']
# ['10']
# ['10']
# ['09']
# ['07']
# ['06']
# ['04']
# ['04']
# ['04']
# ['19']
# ['17']
# ['17']
# ['16']
# ['16']
# ['16']
# ['15']
# ['15']
# ['15']
# ['15']
# ['15']
# ['14']
# ['13']
# ['13']
# ['13']
# ['13']
# ['13']
# ['13']
# ['13']
# ['13']
# ['13']
# ['12']
# ['12']
# ['12']
# ['12']
# ['11']
# ['11']
# ['11']
# ['10']
# ['10']
# ['10']
# ['10']
# ['10']
# ['10']
# ['10']
# ['10']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['08']
# ['18']
# ['18']
# ['17']
# ['17']
# ['17']
# ['16']
# ['16']
# ['15']
# ['15']
# ['15']
# ['14']
# ['12']
# ['12']
# ['11']
# ['11']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['08']
# ['08']
# ['08']
# ['08']
# ['07']
# ['05']
# ['04']
# ['04']
# ['03']
# ['03']
# ['03']
# ['03']
# ['02']
# ['20']
# ['07']
# ['16']
# ['16']
# ['14']
# ['14']
# ['14']
# ['10']
# ['09']
# ['22']
# ['16']
# ['16']
# ['13']
# ['12']
# ['10']
# ['10']
# ['21']
# ['14']
# ['10']
# ['10']
# ['23']
# ['16']
# ['14']
# ['12']
# ['12']
# ['11']
# ['21']
# ['21']
# ['17']
# ['17']
# ['17']
# ['17']
# ['17']
# ['13']
# ['12']
# ['10']
# ['10']
# ['10']
# ['09']
# ['09']
# ['09']
# ['09']
# ['08']
# ['21']
# ['16']
# ['11']
# ['17']
# ['03']
# ['02']
# ['12']
# ['12']
# ['11']
# ['18']
# ['17']
# ['17']
# ['15']
# ['14']
# ['14']
# ['14']
# ['13']
# ['13']
# ['13']
# ['13']
# ['12']
# ['11']
# ['10']
# ['10']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['08']
# ['08']
# ['08']
# ['06']
# ['06']
# ['06']
# ['06']
# ['06']
# ['04']
# ['04']
# ['03']
# ['03']
# ['22']
# ['22']
# ['22']
# ['22']
# ['22']
# ['21']
# ['18']
# ['18']
# ['18']
# ['17']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['15']
# ['15']
# ['15']
# ['14']
# ['13']
# ['13']
# ['11']
# ['11']
# ['10']
# ['10']
# ['10']
# ['10']
# ['10']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['09']
# ['07']
# ['07']
# ['06']
# ['05']
# ['05']
# ['04']
# ['04']
# ['04']
# ['03']
# ['22']
# ['22']
# ['22']
# ['20']
# ['18']
# ['17']
# ['17']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['16']
# ['15']
# ['15']
# ['15']
# ['15']
# ['14']
# ['14']
# ['14']
# ['14']
# ['14']
# ['14']

# %%
import re
x = "We just received $10.00 for cookies." 
y = re.findall('\$[0-9]+.[0-9][0-9]',x)
print(y) # good use of + to grab that greedy

y_test = re.findall('\$[0-9][0-9]',x)
z_test = re.findall('\$[0-9]+',x)
print(y_test, z_test) 

# you can see that it's equivalent
# but using the + makes it much more flexible.
# Out:
# ['$10.00']
# ['$10'] ['$10']
