# %% [markdown]
# # rand7 and rand5
#
# - rand7() creates 1 to 7 integer (inclusive) uniformly
# - rand5() creates 1 to 5 inter (inclusive) uniformly
#
# It's kind of weird that they're asking for two functions that are doing some pretty similar things. Obviously we could do this really simply if we imported numpy lol.

# %%
# Obviously not what they're asking
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def rand7Test(): 
    chosen = np.random.uniform(0.5, 7.5) # excludes 8
    return round(chosen)

# %%
lst = [rand7Test() for i in range(10000)]

# %%
plt.hist(lst, bins='auto', rwidth=1)
# Out:
# (array([ 1433.,     0.,  1431.,     0.,     0.,  1420.,     0.,     0.,
#          1446.,     0.,     0.,  1385.,     0.,     0.,  1420.,     0.,
#          1465.]),
#  array([ 1.        ,  1.35294118,  1.70588235,  2.05882353,  2.41176471,
#          2.76470588,  3.11764706,  3.47058824,  3.82352941,  4.17647059,
#          4.52941176,  4.88235294,  5.23529412,  5.58823529,  5.94117647,
#          6.29411765,  6.64705882,  7.        ]),
#  <a list of 17 Patch objects>)

# %%
sns.distplot(lst)

# %%
def rand8Test(): 
    chosen = np.random.randint(1,8)
    return chosen

# %%
lst2 = [rand8Test() for i in range(1000)]

# %%
plt.hist(lst, bins='auto')
# Out:
# (array([ 1433.,     0.,  1431.,     0.,     0.,  1420.,     0.,     0.,
#          1446.,     0.,     0.,  1385.,     0.,     0.,  1420.,     0.,
#          1465.]),
#  array([ 1.        ,  1.35294118,  1.70588235,  2.05882353,  2.41176471,
#          2.76470588,  3.11764706,  3.47058824,  3.82352941,  4.17647059,
#          4.52941176,  4.88235294,  5.23529412,  5.58823529,  5.94117647,
#          6.29411765,  6.64705882,  7.        ]),
#  <a list of 17 Patch objects>)

# %%
sns.distplot(lst2)
